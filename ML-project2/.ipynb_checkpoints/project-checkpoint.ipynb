# %%
with open('SMSSpamCollection.txt') as file:
    data = file.read()

# %%
splitted_data = data.split('\n')

# %%
# splitted_data[0].split('\t')

x =  []
y = []

for i in splitted_data:
    email_with_tag = i.split('\t')
    if len(email_with_tag) == 2:
        x.append(email_with_tag[1])
        y.append(email_with_tag[0])

# %%
len(x)  , len(y)
# Out:
# (5574, 5574)

# %%
import pandas as pd

# %%
df = pd.DataFrame({'email_message':x,'label':y})
df.head(20)
# Out:
#                                         email_message label
# 0   Go until jurong point, crazy.. Available only ...   ham
# 1                       Ok lar... Joking wif u oni...   ham
# 2   Free entry in 2 a wkly comp to win FA Cup fina...  spam
# 3   U dun say so early hor... U c already then say...   ham
# 4   Nah I don't think he goes to usf, he lives aro...   ham
# 5   FreeMsg Hey there darling it's been 3 week's n...  spam
# 6   Even my brother is not like to speak with me. ...   ham
# 7   As per your request 'Melle Melle (Oru Minnamin...   ham
# 8   WINNER!! As a valued network customer you have...  spam
# 9   Had your mobile 11 months or more? U R entitle...  spam
# 10  I'm gonna be home soon and i don't want to tal...   ham
# 11  SIX chances to win CASH! From 100 to 20,000 po...  spam
# 12  URGENT! You have won a 1 week FREE membership ...  spam
# 13  I've been searching for the right words to tha...   ham
# 14                I HAVE A DATE ON SUNDAY WITH WILL!!   ham
# 15  XXXMobileMovieClub: To use your credit, click ...  spam
# 16                         Oh k...i'm watching here:)   ham
# 17  Eh u remember how 2 spell his name... Yes i di...   ham
# 18  Fine if thatÂ’s the way u feel. ThatÂ’s the wa...   ham
# 19  England v Macedonia - dont miss the goals/team...  spam

# %%
import re   # regular expression

# %%
college = "jecrc FOundation @jaipur 2845445"
re.sub('[^a-zA-Z]',' ',college)
# Out:
# 'jecrc FOundation  jaipur        '

# %%
## text cleaning 
for i in range(len(df)):
    message = re.sub('[^a-zA-Z]',' ',df['email_message'][i])
    message = message.lower()
    df['email_message'][i] = message
# Out:
# C:\Users\kumaw\AppData\Local\Temp\ipykernel_17924\2270161085.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['email_message'][i] = message

# %%
df.head()
# Out:
#                                        email_message label
# 0  go until jurong point  crazy   available only ...   ham
# 1                      ok lar    joking wif u oni      ham
# 2  free entry in   a wkly comp to win fa cup fina...  spam
# 3  u dun say so early hor    u c already then say      ham
# 4  nah i don t think he goes to usf  he lives aro...   ham

# %%
df['label'].value_counts()
# Out:
# label
# ham     4827
# spam     747
# Name: count, dtype: int64

# %%
ham = df[df['label'] == "ham"].sample(1000)
spam = df[df['label'] == 'spam']

# %%
balanced_df = pd.concat([ham,spam])
balanced_df.head()
# Out:
#                                           email_message label
# 4747         orh i tot u say she now still dun believe    ham
# 251        ranjith cal drpd deeraj and deepak  min hold   ham
# 4736               oh k  after that placement there ah    ham
# 5145  hi darlin im on helens fone im gonna b up the ...   ham
# 4740                            we have pizza if u want   ham

# %%
balanced_df['label'] =balanced_df['label'].map({"ham":0,"spam":1})

# %%
balanced_df.head()
# Out:
#                                           email_message  label
# 4747         orh i tot u say she now still dun believe       0
# 251        ranjith cal drpd deeraj and deepak  min hold      0
# 4736               oh k  after that placement there ah       0
# 5145  hi darlin im on helens fone im gonna b up the ...      0
# 4740                            we have pizza if u want      0

# %%
x = balanced_df['email_message']
y = balanced_df['label']

# %%
x = x.values

# ['email 1','email2','email 3']
# Out:
# array(['orh i tot u say she now still dun believe ',
#        'ranjith cal drpd deeraj and deepak  min hold',
#        'oh k  after that placement there ah ', ...,
#        'had your contract mobile    mnths  latest motorola  nokia etc  all free  double mins   text on orange tariffs  text yes for callback  no to remove from records ',
#        'reminder from o   to get      pounds free call credit and details of great offers pls reply   this text with your valid name  house no and postcode',
#        'this is the  nd time we have tried   contact u  u have won the       pound prize    claim is easy  call              now   only   p per minute  bt national rate '],
#       dtype=object)

# %%
# !pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scikit-learn
#   Downloading scikit_learn-1.4.2-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\kumaw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\kumaw\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn) (1.12.0)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.4.2-cp312-cp312-win_amd64.whl (10.6 MB)
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.6 MB 660.6 kB/s eta 0:00:16
#     --------------------------------------- 0.2/10.6 MB 2.0 MB/s eta 0:00:06
#    - -------------------------------------- 0.4/10.6 MB 3.5 MB/s eta 0:00:03
#    --- ------------------------------------ 0.9/10.6 MB 5.4 MB/s eta 0:00:02
#    ------ --------------------------------- 1.7/10.6 MB 7.6 MB/s eta 0:00:02
#    -------- ------------------------------- 2.3/10.6 MB 8.4 MB/s eta 0:00:01
#    ------------ --------------------------- 3.4/10.6 MB 11.6 MB/s eta 0:00:01
#    -------------- ------------------------- 3.8/10.6 MB 10.5 MB/s eta 0:00:01
#    ------------------- -------------------- 5.1/10.6 MB 12.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.1/10.6 MB 13.9 MB/s eta 0:00:01
#    ------------------------- -------------- 6.7/10.6 MB 13.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.5/10.6 MB 14.0 MB/s eta 0:00:01
#    ------------------------------ --------- 8.2/10.6 MB 13.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.1/10.6 MB 14.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.4/10.6 MB 13.7 MB/s eta 0:00:01
#    ---------------------------------------  10.6/10.6 MB 16.4 MB/s eta 0:00:01
#    ---------------------------------------- 10.6/10.6 MB 15.6 MB/s eta 0:00:00
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#    ---------------------------------------- 0.0/301.8 kB ? eta -:--:--
#    --------------------------------------- 301.8/301.8 kB 18.2 MB/s eta 0:00:00
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
# Successfully installed joblib-1.4.2 scikit-learn-1.4.2 threadpoolctl-3.5.0

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
bow = CountVectorizer(max_features=2000,stop_words='english')

# %%
x = bow.fit_transform(x)

# %%
x = x.toarray()

# %%
x.shape ,   y.shape
# Out:
# ((1747, 2000), (1747,))

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test , y_train,y_test = train_test_split(x,y,test_size=0.15)

# %%
# naive bayes 
from sklearn.naive_bayes import MultinomialNB,GaussianNB,BernoulliNB

# %%
mb = MultinomialNB()

# %%
mb.fit(x_train,y_train)
# Out:
# MultinomialNB()

# %%
mb.score(x_train,y_train)
# Out:
# 0.9764150943396226

# %%
mb.score(x_test,y_test)
# Out:
# 0.9239543726235742

# %%
bow

# %%
import joblib 
import pickle

# %%
joblib.dump(mb,'model.lb')
# Out:
# ['model.lb']

# %%
bow
# Out:
# CountVectorizer(max_features=2000, stop_words='english')

# %%
joblib.dump(bow,'bow.lb')
# Out:
# ['bow.lb']
